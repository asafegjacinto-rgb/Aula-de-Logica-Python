# %% [markdown]
# <a href="https://colab.research.google.com/github/asafegjacinto-rgb/Aula-de-Logica-Python/blob/main/C%C3%B3pia_de_papa_l%C3%A9guas_e_coiote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Papa-Léguas")
print("                             __")
print("                            /  \      __")
print(".---.                  _   /   /   _.~  \ ")
print("\    `.               / \ /   /.-~    __/")
print(" `\    \              |  |   |/    .-~ __")
print("   \    \             |  |   |   .'--~~  \ ")
print("    \    \            |  |   `  ' _______/")
print("     \    \           |  `        /")
print(" .--. \    \          |    `     /")
print(" \   `.\    \          \        /")
print("  `\   \     \          `\     (")
print("    \   \     \           > ,-.-.")
print("     \   `.    \         /  |  \ \ ")
print("      \    .    \       /___| O |O\     ,")
print("   .-. \    ;    |    /`    `^-.\.-'`--'/")
print("   \  `;         |   |                 /")
print("    `\  \        |   `.     `--..____,'")
print("      \  `.      |     `._     _.-'^")
print("       \   .     /         `|`|`")
print("     .-.\       /           | |")
print("     \  `\     /            | |")
print("      `\  `   |             | |")
print("        \     |             | |")
print("       .-.    |             | |")
print("       \  `.   \            | |")
print("        `\      \           | |")
print("          \      \          | |")
print("           \_____ :-'~~~~~'-' ;")
print("           /____;``-.         :")
print("          <____(     `.       ;")
print("            \___\     ;     .'")
print("               /``--'~___.-'")
print("              /\___/^/__/")
print("             /   /' /`/'")
print("             \  \   `\ \ ")
print("              `\ \    \ \ ")
print("                \ \    \ \ ")
print("                 \ \    \ \ ")
print("                  \ \    \ \     ______")
print("                   \ \ ___\ \'~``______)>")
print("                    \ \___ _______ __)>")
print("                _____\ \'~``______)>")
print("              <(_______.._______)>")



print("Wile E Coyote")
print("                      _")
print("                     : \ ")
print("                     ;\ \_                   _")
print("                     ;@: ~:              _,-;@)")
print("                     ;@: ;~:          _,' _,'@;")
print("                     ;@;  ;~;      ,-'  _,@@@,'")
print("                    |@(     ;      ) ,-'@@@-;")
print("                    ;@;   |~~(   _/ /@@@@@@/")
print("                    \@\   ; _/ _/ /@@@@@@;~")
print("                     \@\   /  / ,'@@@,-'~")
print("                       \\  (  ) :@@(~")
print("                    ___ )-'~~~~`--/ ___")
print("                   (   `--_    _,--'   )")
print("                  (~`- ___ \  / ___ -'~)")
print("                 __~\_(   \_~~_/   )_/~__")
print(" /\ /\ /\     ,-'~~~~~`-._ 0\/0 _,-'~~~~~`-.")
print("| |:  ::|    ;     ______ `----'  ______    :")
print("| `'  `'|    ;    {      \   ~   /      }   |")
print(" \_   _/     `-._      ,-,' ~~  `.-.      _,'        |\ ")
print("   \ /_          `----' ,'       `, `----'           : \ ")
print("   |_( )                `-._/#\_,-'                  :  )")
print(" ,-'  ~)           _,--./  (###)__                   :  :")
print(" (~~~~_)          /       ; `-'   `--,               |  ;")
print(" (~~~' )         ;       /@@@@@@.    `.              | /")
print(" `.HH~;        ,-'  ,-   |@@@ @@@@.   `.             .')")
print("  `HH `.      ,'   /     |@@@@@ @@@@.  `.           / /(~)")
print("   HH   \_   ,'  _/`.    |@@@@@ @@@@@;  `.          ; (~~)")
print("   ~~`.   \_,'  /   ;   .@@@@@ @@@@@@;\_  \___      ; H~\)")
print("       \_     _/    `.  |@@@@@@ @@@@@;  \     `----'_HH[~)")
print("         \___/       `. :@@@@@ @@@@@@'   \__,------' HH ~")
print("        ______        ; |@@@@@@ @@@'                 HH")
print("      _)      \_,     ; :@@@@@@@@@;                  ~~")
print("    _;          \\   ,' |@@@@@@@@@:")
print("  ,'     ; :      \_,   :@@@@@@@@@@.")
print("  `.__,-'~~`._,-.  ,    :@@@@@@@@@@`.")
print("                 \/    /@@@@@@@@@@@@:")
print("                 /    ,@@@@@@@@@@@@@@.")
print("                |    ,@@@@@@@@@@@@@@@:")
print("                |    :@@@@@@@@@@@@@@@'")
print("                `.   \@@@@/  `@@@@@/(")
print("                  )   ~~~/    \~~~~  \ ")
print("                  :     /       \_    \ ")
print("                  (    /          \_   `. ")
print("                  /   ;             \_  `.")
print("                 /   /                \  `.")
print("               /   /                  `.  \ ")
print("              ,'  ,'/~~)                ;  / ")
print("              {   `'   (               /  /")
print("              `.___,-'  \             /  /")
print("                 __/     |           /  /")
print("                /        |           : :   __ ")
print("                :        |           ; : _;  )__")
print("                (  |  |  /          /  `,'  ~   )_")
print("                 `-:__;-'          :  ,'      ~~  ;")
print("                                  /          (_,--'")
print("                                 (       ,-'~~")
print("                                  \__,-'~")
# Out:
# Papa-Léguas
#                              __
#                             /  \      __
# .---.                  _   /   /   _.~  \
# \    `.               / \ /   /.-~    __/
#  `\    \              |  |   |/    .-~ __
#    \    \             |  |   |   .'--~~  \
#     \    \            |  |   `  ' _______/
#      \    \           |  `        /
#  .--. \    \          |    `     /
#  \   `.\    \          \        /
#   `\   \     \          `\     (
#     \   \     \           > ,-.-.
#      \   `.    \         /  |  \ \
#       \    .    \       /___| O |O\     ,
#    .-. \    ;    |    /`    `^-.\.-'`--'/
#    \  `;         |   |                 /
#     `\  \        |   `.     `--..____,'
#       \  `.      |     `._     _.-'^
#        \   .     /         `|`|`
#      .-.\       /           | |
#      \  `\     /            | |
#       `\  `   |             | |
#         \     |             | |
#        .-.    |             | |
#        \  `.   \            | |
# ...
